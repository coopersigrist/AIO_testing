# %% [markdown]
# # Linear Algebra Test
#
# Each section will have different time limits, complete what you can within that time. These are similar difficulty (if not a little easier than the AIO qualifying exam)

# %% [markdown]
# ## Section 1 : Norms (10 min)
#
# Given the following matrix A and arbitrary matrix X,
#
# $\vec{A} = \begin{bmatrix} 1 & 2 \\\ 3 & 4 \end{bmatrix} \quad \vec{x} = \begin{bmatrix} x1 \\\ x2 \end{bmatrix}$
#
#  determine the following:

# %% [markdown]
# $||A||_{1,1} = \\$
# $||A||_{2,2} = \\$
# $||A||_{\infty, \infty} = \\$

# %% [markdown]
# Under what conditions (settings of x) are the following true?
#
# $||Ax||_1 > ||A||_{1,1} \\$
# $||Ax||_\infty > ||A||_{\infty, \infty} \\$

# %% [markdown]
# Complete the following code to implement a calculation of the L-n norm of a matrix, given as a 2d Numpy array

# %%
import numpy as np

def calc_l_n_norm(A, n):
    '''
    parameters:
    - A is some 2 dimensional matrix (np array)
    - n is the norm to calculate

    returns:
    - The L-n norm of the matrix A
    '''

    pass

# %% [markdown]
# ## Section 2: Determinants and eigenvectors (10 min)
#
# Given the following matrix F
#
# $\vec{F} = \begin{bmatrix} 1 & 1 \\\ 1 & 0 \end{bmatrix}$
#
# determine the following:

# %% [markdown]
# #### What is the determinant of F?

# %% [markdown]
# det(F) =

# %% [markdown]
# #### List all eigenvectors of F with their corresponding eigenvalues

# %% [markdown]
# $\lambda_1 =  \quad \quad \vec{v_1} = \\ \\$
# $\lambda_2 =  \quad \quad \vec{v_2} = $

# %% [markdown]
# ## Section 3: Powers of Matrices (20 min)
#
# This section will use the same matrix F as above and will work through an interesting calculation you can do with it.

# %% [markdown]
# #### First, calculate the next two powers of this matrix:
#
# $F^2 = \\$
# $F^3 = \\$
#
# Do you recognize anything about these values? (Hint: the letter choice F is not arbitray, consider sequences you may have seen)

# %% [markdown]
# #### Next, rewrite the matrix F using the eigenvalues and eigenvectors calculated above (Hint: recall that for a matrix A with eigenvector, v, with corresponding eigenvalue, $\lambda$, $Av =  v * \lambda$, what happens for a matrix of all eigen vectors?):
#
# $F = $

# %% [markdown]
# #### What happens if we raise both sides to the power n? Justify Mathematically
#
# $F^n = $

# %% [markdown]
# #### Lastly, use this to calculate the n-th fibonacci number using only 2, fixed-size matrix multiplications. Code your solution.

# %%
def fibonacci(n):
    '''
    Returns the n-th fibonacci number using only matrix operations. 
    You should use Numpy for this -- re-import it if necessary
    '''

    pass
